# %%
# Creating file from python and writing 
f = open('hello.txt','w')
f.write ("This is my first file from python")
f.close()

# %%
# reading into file 
f = open('hello.txt','r')
print(f.read())
f.close()
# Out:
# This is my first file from python

# %%
f.closed
# Out:
# True

# %%
print('he') # YO Run hunch 
1 /0
print('hello') # yo chai run hudaina
# Out:
# he
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 print('he')
# ----> 2 1 /0
#       3 print('hello')
#
# ZeroDivisionError: division by zero

# %%
# reading into file 
f = open('hello.txt','r')
print(f.read())
1 / 0
f.close()
# Out:
# This is my first file from python
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 f = open('hello.txt','r')
#       3 print(f.read())
# ----> 4 1 / 0
#       5 f.close()
#
# ZeroDivisionError: division by zero

# %%
f. closed
# Out:
# False

# %%
# error /  exception handling 
def division (a,b):
    try:
        div = a / b 
        return div
    # except ZeroDivisionError:
    #     print('Cannot divide by 0.')   
    # except TypeError:
    #     print('Invalid datatype')
    except Exception as e:    # yeaslea chai sabai erro handle garcha 
        print(e)
division(4,0)
division(4,"b")
# Out:
# division by zero
# unsupported operand type(s) for /: 'int' and 'str'

# %%
def division (a,b):
    try:
        div = a / b 
        return "i will run if there is no exception", div
    # except ZeroDivisionError:
    #     print('Cannot divide by 0.')   
    # except TypeError:
    #     print('Invalid datatype')
    except Exception as e:    # yeaslea chai sabai erro handle garcha 
        print(e)
    finally:
        print("i wil run no matter what happens in the code.")
division(4,2)
# Out:
# ('i will run if there is no exception\n', 2.0)

# %%
p = open ('hello.txt', "r")
print (f. read ())
try :
    1 / 0 
except Exception as e:
    print(e)
p.close()
# Out:
# division by zero

# %%
p.closed
# Out:
# True

# %%
with open ('hello.txt','w') as f:
    f.write('Hello world')
f.closed
# Out:
# True

# %%
with open ('hello.txt', 'r') as f :
    print (f.closed)
    print(f.read())
    print(f.closed)
print(f.closed)
# Out:
# False
# Hello world
# False
# True

# %%
with open ('hello.txt', 'r') as f :
    print (f.closed)
    print(f.read())
    1 / 0 
f.closed
# Out:
# False
# Hello world
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[28], line 4
#       2     print (f.closed)
#       3     print(f.read())
# ----> 4     1 / 0
#       5 f.closed
#
# ZeroDivisionError: division by zero

# %%
f.closed
# Out:
# True

# %%
with open('hello.txt','r') as f:
    print(f.read())
# Out:
# Hello world

# %%
with open ('python_logo.jpeg','rb')as f:  # image haru lai read garna chai binary mode ma garna parcha
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\n\x07\x08\x12\x12\x11\x11\x15\x11\x12\x19\x19\x10\x14\x12\x18\x15\x14\x12\x12\x19\x11\x12\x11\x12\x1c\x1a\x1a\x1a\x19\x18\x15\x18\x18\x1c#.%\x1c!+\x1f\x18\x18(8&+=1555\x1c$;@=4?.451\x01\x0c\x0c\x0c\x10\x0f\x10\x1e\x12\x12\x1e<$$\'1145444?5444=4>441=5444414444444?44441444444444444\xff\xc0\x00\x11\x08\x00\xe1\x00\xe1\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x01\x00\x01\x05\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\